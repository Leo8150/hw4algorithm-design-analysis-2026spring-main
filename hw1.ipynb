# %% [markdown]
# ## algorithm design and anlysis-2026 spring  homework 1
# **Deadline**：2026.5.20
#
# **name**:
#
#
# note：
# ---
# 1. 带有\*的题目，申请免上课的同学，必须完成，其他同学选作；
# 2. 请独立完成，如求助了他人或者大模型，请著明，并且不可省略算法分析部分；
# 4. 如若作答有雷同，全部取消成绩；
# 3. 需要书面作答的题目，可以通过引用图片的形式添加，但是注意上传项目时包含所引用的图片的源文件；
# 4. $log_n$ 默认表示$log_2{n}$;

# %% [markdown]
# ## 问题 1
#
# 根据下列递归公式, 计算下列 $T(n)$ 对应的的渐近上界。要求所求的边界尽可能的紧（tight）, 请写明步骤。
#
# 1. $T(1)=1; T(n)=T(n/4)+1$ for $n>1$
# 2. $T(1)=1;T(n)=3T(n/3)+n^2$ for $n>1$
# 3. $T(1)=1;T(n)=T(2n/3)+1$ for $n>1$
# 4. $T(1)=1;T(n)=5T(n/4)+n$ for $n>1$
# 5. $T(n)=1 \ for\ n \le 2 ; T(n)=T(\sqrt{n})+1 \ for \ n>2$

# %% [markdown]
# idea:
#
# 1. $T(n)=T(n/4)+1$。每次递归把规模缩小为原来的 $1/4$，直到规模为 1。递归层数满足 $n/4^k=1$，即 $k=\log_4 n$。每层只做常数工作，所以 $T(n)=\Theta(\log n)$。
#
# 2. $T(n)=3T(n/3)+n^2$。由 Master 定理，$a=3,b=3$，$n^{\log_b a}=n$。这里 $f(n)=n^2$ 比 $n$ 多一个多项式因子，并满足 regularity condition，因此 $T(n)=\Theta(n^2)$。
#
# 3. $T(n)=T(2n/3)+1$。规模每次乘以 $2/3$，递归层数满足 $(2/3)^k n\le 1$，所以 $k=\Theta(\log n)$。每层常数代价，所以 $T(n)=\Theta(\log n)$。
#
# 4. $T(n)=5T(n/4)+n$。由 Master 定理，$a=5,b=4$，$n^{\log_4 5}\approx n^{1.161}$，而 $f(n)=n=O(n^{\log_4 5-\epsilon})$，因此 $T(n)=\Theta(n^{\log_4 5})$。
#
# 5. $T(n)=T(\sqrt n)+1$。令 $m=\log_2 n$，并设 $S(m)=T(2^m)$，则 $\sqrt n=2^{m/2}$，所以 $S(m)=S(m/2)+1$。因此 $S(m)=\Theta(\log m)$，即 $T(n)=\Theta(\log\log n)$。

# %% [markdown]
# ## 问题 2
#
# 观察下方的分治算法（divide-and-conquer algorithm）的伪代码, 回答下面问题
#
# ```latex
# DoSomething(A,p,r)
# -----
# n := r-p+1
# if n=2 and A[p]>A[r] then
#     swap A[p] and A[r]
# else if n >= 3 then
#     m = ceil(2n/3)
#     DoSomething(A,p,p+m-1)
#     DoSomething(A,r-m+1,r)
#     DoSomething(A,p,p+m-1)
#
# ---
# first call: DoSomething(A,1,n)
# ```
#
# note：$ceil(2n/3)=\left\lceil {2n/3} \right\rceil$；$:=$ 表示赋值, 等价于 $\to$；A是一个包含n的整数元素的数组,
#
# 1. 写出该算法时间复杂度的递归公式, 并求解其对应的渐进表示
# 2. 描述一下该算法的功能, 并判断是否是最高效的解决方案
# 3. \* 使用python编程实现上述算法或其对应的更高效版本的算法

# %% [markdown]
# idea:
#
# 1. 设输入规模为 $n$，每次递归调用 3 次规模约为 $2n/3$ 的子问题，除递归外只做常数次比较、赋值和交换，所以递归式为：
#
# $T(n)=3T(\lceil 2n/3\rceil)+O(1)$。
#
# 忽略取整后，递归树每层问题规模乘以 $2/3$，分支数为 3，因此由 Master 定理可得 $T(n)=\Theta(n^{\log_{3/2}3})\approx\Theta(n^{2.71})$。
#
# 2. 该算法是 Stooge Sort 的一种形式，可以将数组升序排序。它不是最高效的排序算法，因为其时间复杂度约为 $O(n^{2.71})$，比归并排序、堆排序等 $O(n\log n)$ 的比较排序算法低效。

# %%
# add your code here
# your algorithm time complexity is:

# %% [markdown]
# ## 问题 3
#
# 给定一个包含n个元素的数组 `profits` , 它的第 `i` 个元素 `profits[i]` 表示一支股票第 `i` 天的**收益**（正数表示涨, 负数表示跌）。你只能选择 **某一天** 买入这只股票, 并选择在 **未来的某一个不同的日子** 卖出该股票。
#
# 1. 设计一个算法来计算你所能获取的最大利润和对应买入和卖出的日期。请分析算法方案, 计算其时间复杂度, 并且使用python编程实现该算法。
#
# 2. \* 设计一个时间复杂度为 $O(n)$的算法实现该算法
#
# e.g. :
# ---
# profits=[3,2,1,-7,5,2,-1,3,-1], 第5天买入, 第8天卖出, 收益最大：9

# %% [markdown]
# idea:
#
# 把 `profits[i]` 看成第 `i+1` 天持有股票获得的收益。若选择第 $i$ 天买入、第 $j$ 天卖出，并且卖出日必须晚于买入日，则需要枚举所有满足 $i<j$ 的连续区间，计算 `profits[i..j]` 的连续和，记录最大值及其左右端点。
#
# 算法：外层枚举买入日 `i`，内层从 `i+1` 开始枚举卖出日 `j`，并维护从 `i` 到 `j` 的累计收益。每得到一个更大的累计收益，就更新最大收益和对应日期。时间复杂度 $O(n^2)$，空间复杂度 $O(1)$。

# %%
# add your code here
def max_profit_days(profits):
    if len(profits) < 2:
        return None, None, None

    best = float("-inf")
    best_buy = best_sell = None
    n = len(profits)
    for i in range(n - 1):
        current = profits[i]
        for j in range(i + 1, n):
            current += profits[j]
            if current > best:
                best = current
                best_buy = i + 1
                best_sell = j + 1
    return best, best_buy, best_sell


profits = [3, 2, 1, -7, 5, 2, -1, 3, -1]
profit, buy_day, sell_day = max_profit_days(profits)
print(f"max profit: {profit}, buy day: {buy_day}, sell day: {sell_day}")

# your algorithm time complexity is:
# O(n^2)
# Out:
# max profit: 9, buy day: 5, sell day: 8

# %% [markdown]
# ## 问题 4
#
# 给定一个包含不同整数元素的数组 $ A[1..n]$ ,并且满足条件：$A[1]>A[2]$ 并且 $A[n-1]<A[n]$; 规定：如果一个元素比它两边的邻居元素都小, 即：$A[x]<A[x-1], A[x]<A[x+1]$ , 称这个元素A[x]为“局部最小”。通过遍历一次数组, 我们可以很容易在 $O(n)$的时间复杂度下找到一个局部最小值,
#
#
# 1. 分析该问题, 设计一个算法在$O(logn)$的时间复杂度下找到一个局部最小(返回数值), 要求：分析算法设计思路, 并且使用python编程实现
# 2. \* 设计算法找出所有局部最小值, 分析算法设计思路, 并使用python编程实现
#
# e.g.:
# ---
# A=[9, 3, 7, 2, 1, 4, 5 ] 时,  局部最小元素为 3, 1

# %% [markdown]
# idea:
#
# 由于 $A[1]>A[2]$ 且 $A[n-1]<A[n]$，数组左端存在下降趋势，右端存在上升趋势，因此中间一定至少存在一个“谷底”式的局部最小。可以用二分查找：
#
# 取中点 `mid`。若 `A[mid] < A[mid-1]` 且 `A[mid] < A[mid+1]`，则直接返回 `A[mid]`。若左邻居更小，即 `A[mid-1] < A[mid]`，说明向左存在下降方向，左半边一定能找到局部最小；否则右半边一定能找到局部最小。每次把搜索区间缩小一半。
#
# 时间复杂度为 $O(\log n)$，空间复杂度为 $O(1)$。

# %%
# add your code here
def find_one_local_min(A):
    if len(A) < 3:
        return None
    left, right = 1, len(A) - 2
    while left <= right:
        mid = (left + right) // 2
        if A[mid] < A[mid - 1] and A[mid] < A[mid + 1]:
            return A[mid]
        if A[mid - 1] < A[mid]:
            right = mid - 1
        else:
            left = mid + 1
    return None


A = [9, 3, 7, 2, 1, 4, 5]
print("找到的一个局部最小:", find_one_local_min(A))

# your algorithm time complexity is:
# O(log n)
# Out:
# 找到的一个局部最小: 1

# %% [markdown]
# ## 问题 5
#
# 给定包含n个不同数字的一组数, 寻找一种基于比较的算法在这组数中找到k个最小的数字, 并按顺序输出它们。
#
# 1. 将n个数先进行排序, 然后按顺序输出最小的k个数。要求：选择合适的排序算法实现上述操作, 计算算法时间复杂度, 并使用python编程实现。
# 2. 建立一个包含这n个数的堆（heap）, 并且调用 k 次Extract-min 按顺序输出最小的k个数。使用往空堆中不断插入元素的方法建立堆, 分析这种方法建堆的时间复杂度, 并使用python编程实现
# 3. \* 假设数组中包含的数据总数目超过了计算机的存储能力, 请设计一个算法, 找到这堆数据的前k小的数值, 计算时间复杂度, 并使用python实现该算法, 假设计算机一定能存储k个数据。
#
# e.g.：
# ---
# 数组arr=[5,4,3,2,6,1,88,33,22,107] 的前3个最小数据为：1, 2, 3

# %% [markdown]
# idea:
#
# 1. 排序法：先把 $n$ 个数整体排序，再输出前 $k$ 个。这里使用归并排序。归并排序递归地把数组分成两半，分别排序后再合并，排序时间复杂度为 $O(n\log n)$，输出前 $k$ 个为 $O(k)$，总时间复杂度为 $O(n\log n+k)=O(n\log n)$，空间复杂度为 $O(n)$。
#
# 2. 堆方法：从空堆开始，把 $n$ 个元素逐个插入最小堆。一次插入最多上浮 $O(\log n)$ 层，因此逐个插入建堆的时间复杂度是 $O(n\log n)$。之后执行 $k$ 次 `Extract-min`，每次代价 $O(\log n)$，所以总时间复杂度为 $O((n+k)\log n)$，空间复杂度为 $O(n)$。

# %%
# add your code here
import heapq
def merge_sort(arr):
    if len(arr) <= 1:
        return arr[:]
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    i = j = 0
    result = []
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result


def k_smallest_by_sort(arr, k):
    return merge_sort(arr)[:k]


def k_smallest_by_heap(arr, k):
    heap = []
    for x in arr:
        heapq.heappush(heap, x)
    return [heapq.heappop(heap) for _ in range(min(k, len(heap)))]


arr = [5, 4, 3, 2, 6, 1, 88, 33, 22, 107]
k = 3
print("排序法:", k_smallest_by_sort(arr, k))
print("最小堆法:", k_smallest_by_heap(arr, k))

# your algorithm time complexity is:
# sort method O(n log n); heap method O((n+k) log n)
# Out:
# 排序法: [1, 2, 3]
# 最小堆法: [1, 2, 3]

# %% [markdown]
# ## 问题 6
#
# > 星球碰撞问题：现有n个星球，在同一条直线上运行，如数组A所示，元素的绝对值表示星球的质量，负数表示星球自右向左运动，正数表示星球自左向右运动，当两个星球相撞的时候，质量小的会消失，大的保持不变，**质量相同的两个星球碰撞后自右向左运动的星球消失，自左向右的星球保持不变**，假设所有星球的速度大小相同。
# >
# > $ A=[23,-8, 9, -3, -7, 9, -23, 22] $
#
# 请设计一个算法模拟星球的运行情况，输出最终的星球存续情况（输出一个数组），分析算法设计思路，计算时间复杂度，并基于python编程实现。
#
# e.g.
# ---
# 1.  输入： A=[-3,-6,2,8, 5,-8,9,-2,1]， 输出：[-3, -6, 2, 8, 9, 1]
#
# 2. 输入：A=[23,-8, 9, -3, -7, 9, -23, 22], 输出：[23, 22]

# %% [markdown]
# idea:
#
# 使用栈保存当前仍然存活的星球。只有当栈顶星球向右运动（正数）且当前星球向左运动（负数）时，二者才会相撞。比较二者质量：
#
# - 若栈顶质量更小，栈顶星球消失，当前星球继续尝试与新的栈顶碰撞；
# - 若栈顶质量更大，当前星球消失；
# - 若质量相同，根据题意，向左运动的星球消失，向右运动的栈顶星球保留。
#
# 每个星球最多进栈一次、出栈一次，因此时间复杂度 $O(n)$，空间复杂度 $O(n)$。

# %%
# add your code here
def asteroid_collision(A):
    stack = []
    for x in A:
        alive = True
        while alive and stack and stack[-1] > 0 and x < 0:
            if abs(stack[-1]) < abs(x):
                stack.pop()
            else:
                alive = False
        if alive:
            stack.append(x)
    return stack


tests = [
    [-3, -6, 2, 8, 5, -8, 9, -2, 1],
    [23, -8, 9, -3, -7, 9, -23, 22],
]
for A in tests:
    print(A, "=>", asteroid_collision(A))

# your algorithm time complexity is:
# O(n)
# Out:
# [-3, -6, 2, 8, 5, -8, 9, -2, 1] => [-3, -6, 2, 8, 9, 1]
# [23, -8, 9, -3, -7, 9, -23, 22] => [23, 22]

# %% [markdown]
# ## 问题 7
#
# > 0-1背包问题：现在有4块大理石，每个大理石对应的重量和价值使用一个元组表示, 即（重量，价值），4块大理石的重量和价值为：[(5,10), (4,40), (6,30), (3, 50)], 假设你有一辆最大承重为9的小推车，请问使用这个小推车装大理石的最大价值为多少
#
# 请设计一个算法解决该问题，分析算法设计思路，计算时间复杂度，并基于python编程实现

# %% [markdown]
# idea:
#
# 这是 0-1 背包问题。令 `dp[c]` 表示当前已考虑若干大理石时，容量不超过 `c` 能得到的最大价值。对每块大理石 `(weight, value)`，容量 `c` 从大到小更新：
#
# `dp[c] = max(dp[c], dp[c-weight] + value)`
#
# 容量倒序更新可以保证每块大理石只被选择一次。设大理石数量为 $n$，背包容量为 $W$，时间复杂度 $O(nW)$，空间复杂度 $O(W)$。本题中 $n=4,W=9$。

# %%
# add your code here
def knapsack_01(items, capacity):
    dp = [0] * (capacity + 1)
    for weight, value in items:
        for c in range(capacity, weight - 1, -1):
            dp[c] = max(dp[c], dp[c - weight] + value)
    return dp[capacity]


items = [(5, 10), (4, 40), (6, 30), (3, 50)]
capacity = 9
print("最大价值:", knapsack_01(items, capacity))

# your algorithm time complexity is:
# O(nW)
# Out:
# 最大价值: 90

# %% [markdown]
# ## 问题 8
#
# 给你二叉搜索树的根节点 root ，该树中的恰好两个节点的值被错误地交换。请在不改变其结构的情况下，恢复这棵树 。设计算法解决该问题，分析算法设计思路，计算时间复杂度，并基于python编程实现
#
# e.g.:
# ---
# 1.
#
# <div style="text-align:center;width:200px;"> <img alt="" src="./fig/hw3q9-1.jpg"> </div>
# 输入：root = [1,3,null,null,2]， 输出为：[3,1,null,null,2]，
#
# 解释：3 不能是 1 的左孩子，因为 3 > 1 。交换 1 和 3 使二叉搜索树有效。
#
# 2.
#
#  <div style="text-align:center;width:200px;"> <img alt="" src="./fig/hw3q9-1.jpg"> </div>
# 输入： root=[3,1,4,null,null,2]， 输出为：[2,1,4,null,null,3]
#
# 解释：2 不能在 3 的右子树中，因为 2 < 3 。交换 2 和 3 使二叉搜索树有效。

# %% [markdown]
# idea:
#
# 二叉搜索树的中序遍历结果应该是严格递增序列。若恰好两个节点的值被交换，则中序遍历序列中会出现一个或两个逆序位置。
#
# 算法：中序遍历整棵树，并保存上一个访问节点 `prev`。当发现 `prev.val > current.val` 时，说明出现逆序。第一次出现逆序时，记录 `first=prev`，并记录 `second=current`；如果之后再次出现逆序，则把 `second` 更新为新的 `current`。遍历结束后交换 `first` 和 `second` 的值即可恢复二叉搜索树，树的结构不变。
#
# 时间复杂度 $O(n)$，递归栈空间复杂度 $O(h)$，其中 $h$ 是树高。

# %%
# add your code here
from collections import deque


class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


def build_tree(values):
    if not values or values[0] is None:
        return None
    root = TreeNode(values[0])
    q = deque([root])
    i = 1
    while q and i < len(values):
        node = q.popleft()
        if i < len(values) and values[i] is not None:
            node.left = TreeNode(values[i])
            q.append(node.left)
        i += 1
        if i < len(values) and values[i] is not None:
            node.right = TreeNode(values[i])
            q.append(node.right)
        i += 1
    return root


def tree_to_list(root):
    if root is None:
        return []
    ans = []
    q = deque([root])
    while q:
        node = q.popleft()
        if node is None:
            ans.append(None)
        else:
            ans.append(node.val)
            q.append(node.left)
            q.append(node.right)
    while ans and ans[-1] is None:
        ans.pop()
    return ans


def recover_tree(root):
    first = second = prev = None

    def inorder(node):
        nonlocal first, second, prev
        if node is None:
            return
        inorder(node.left)
        if prev is not None and prev.val > node.val:
            if first is None:
                first = prev
            second = node
        prev = node
        inorder(node.right)

    inorder(root)
    if first is not None and second is not None:
        first.val, second.val = second.val, first.val
    return root


for values in ([1, 3, None, None, 2], [3, 1, 4, None, None, 2]):
    root = build_tree(values)
    recover_tree(root)
    print(values, "=>", tree_to_list(root))

# your algorithm time complexity is:
# O(n)
# Out:
# [1, 3, None, None, 2] => [3, 1, None, None, 2]
# [3, 1, 4, None, None, 2] => [2, 1, 4, None, None, 3]

# %% [markdown]
# ## 问题 9 \*
# 给定 `n` 个非负整数表示每个宽度为 `1` 的柱子的高度图，计算按此排列的柱子，下雨之后能接多少雨水。
#
#
#
# <div style="text-align:center;width:800px;"> <img alt="" src="./fig/hw3q6.png"> </div>
#
# 请分析算法设计思路，计算时间复杂度，并基于python编程实现

# %% [markdown]
# idea:

# %%
# add your code here
# your algorithm time complexity is:

# %% [markdown]
# ## 问题 10
#
# 给你一个二叉树的根节点 root ，树中每个节点都存放有一个 0 到 9 之间的数字。每条从根节点到叶节点的路径都代表一个数字：
#
# > 例如，从根节点到叶节点的路径 1 -> 2 -> 3 表示数字 123 。
#
# 设计一个算法计算从根节点到叶节点生成的所有数字之和 ，分析算法设计思路，计算时间复杂度，并基于python编程实现
#
# 叶节点:是指没有子节点的节点。
#
# e.g.:
# ---
# 1.
#
#  <div style="text-align:center;width:200px;"> <img alt="figure" src="./fig/hw3q10-1.jpg"> </div>
#
#  输入：root = [1,2,3], 输出：25
#
# 解释：从根到叶子节点路径 1->2 代表数字 12，1->3 代表数字 13，因此和为 12 + 13 = 25 。
#
# 2.
#
#  <div style="text-align:center;width:200px;"> <img alt="figure" src="./fig/hw3q10-2.jpg"> </div>
#
#  输入：root = [4,9,0,5,1], 输出：1026
#
# 解释：从根到叶子节点路径 4->9->5 代表数字 495，4->9->1 代表数字 491，4->0 代表数字 40。因此和为 495 + 491 + 40 = 1026 。

# %% [markdown]
# idea:
#
# 使用深度优先搜索。递归函数携带当前路径已经形成的数字 `current`。当访问值为 `v` 的节点时，新的路径数字变为 `current * 10 + v`。如果当前节点是叶节点，就返回这个完整数字；否则递归计算左右子树，并把左右结果相加。
#
# 每个节点只访问一次，所以时间复杂度 $O(n)$。递归栈深度等于树高，空间复杂度 $O(h)$。

# %%
# add your code here
from collections import deque


class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


def build_tree(values):
    if not values or values[0] is None:
        return None
    root = TreeNode(values[0])
    q = deque([root])
    i = 1
    while q and i < len(values):
        node = q.popleft()
        if i < len(values) and values[i] is not None:
            node.left = TreeNode(values[i])
            q.append(node.left)
        i += 1
        if i < len(values) and values[i] is not None:
            node.right = TreeNode(values[i])
            q.append(node.right)
        i += 1
    return root


def sum_numbers(root):
    def dfs(node, current):
        if node is None:
            return 0
        current = current * 10 + node.val
        if node.left is None and node.right is None:
            return current
        return dfs(node.left, current) + dfs(node.right, current)

    return dfs(root, 0)


for values in ([1, 2, 3], [4, 9, 0, 5, 1]):
    print(values, "=>", sum_numbers(build_tree(values)))

# your algorithm time complexity is:
# O(n)
# Out:
# [1, 2, 3] => 25
# [4, 9, 0, 5, 1] => 1026
